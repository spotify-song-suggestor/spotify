# %%
import pandas as pd
import plotly.express as px

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
p_artists = df.groupby("artists")['popularity'].sum().sort_values(ascending=False)[:1000]
words = p_artists.index.str.split("(").str[0].value_counts().keys()
wordcloud = WordCloud(scale=5,max_words=1000,colormap="rainbow",background_color="white").generate(" ".join(words))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud.to_file('cloud.png')
